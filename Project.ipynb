# %%
import pandas as pd
import matplotlib.pyplot as plt
from skimage.io import imread
from skimage.transform import resize
 
# Opencv - BGR2GRAY
# Skimage = rgb2gray

# %%
# Displaying the image
path = '/content/drive/MyDrive/pictures/bikes/images (3).jpg'
img = plt.imread(path)
plt.imshow(img)
img
# Out:
# array([[[ 94, 103,  56],
#         [ 99, 111,  61],
#         [ 76,  88,  38],
#         ...,
#         [ 71,  79,  22],
#         [ 86,  93,  39],
#         [ 76,  83,  29]],
#
#        [[ 91, 104,  51],
#         [ 96, 109,  56],
#         [ 80,  93,  40],
#         ...,
#         [ 72,  79,  25],
#         [ 88,  95,  41],
#         [ 79,  86,  32]],
#
#        [[103, 116,  60],
#         [ 91, 104,  48],
#         [ 67,  81,  22],
#         ...,
#         [ 61,  70,  15],
#         [ 78,  85,  31],
#         [ 72,  79,  25]],
#
#        ...,
#
#        [[154, 150, 102],
#         [154, 150, 102],
#         [151, 145,  97],
#         ...,
#         [150, 142,  95],
#         [150, 142,  95],
#         [149, 141,  94]],
#
#        [[157, 153, 105],
#         [156, 152, 104],
#         [149, 145,  97],
#         ...,
#         [147, 139,  90],
#         [147, 139,  90],
#         [146, 138,  89]],
#
#        [[159, 155, 107],
#         [157, 153, 105],
#         [149, 145,  97],
#         ...,
#         [158, 148,  99],
#         [158, 148,  99],
#         [158, 148,  99]]], dtype=uint8)

# %%
img.shape
# Out:
# (168, 299, 3)

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from skimage.io import imread
from skimage.transform import resize

datadir = '/content/drive/MyDrive/pictures'

categories = ['bikes','cars'] # Name the folder with these categories
target = []
flat_data = []

for i in categories:
  path = os.path.join(datadir,i)
  #print(path)
  for img in os.listdir(path):
    print(img)
    img_array = imread(os.path.join(path,img))

    img_resize = resize(img_array,(150,150,3)) # Value gets converted 0-1 from 0-255
    flat_data.append(np.ndarray.flatten(img_resize))
    target.append(i)
    plt.imshow(img_resize)
    plt.show()

flat_data = np.array(flat_data)
target = np.array(target)
# Out:
# download.jpg
# images.jpg
# images (2).jpg
# images (3).jpg
# download (1).jpg
# images (4).jpg
# images (5).jpg
# images (6).jpg
# images (8).jpg
# download (2).jpg
# download (3).jpg
# images (2).jpg
# download.jpg
# download (1).jpg
# download (2).jpg
# images.jpg
# images (1).jpg
# download (3).jpg
# images (4).jpg
# images (5).jpg
# download (4).jpg
# download (5).jpg
# images (6).jpg
# download (6).jpg

# %%
df = pd.DataFrame(flat_data)
df['Target'] = target
df.head()
# Out:
#           0         1         2         3  ...     67497     67498     67499  Target
# 0  0.996078  0.996078  0.996078  0.996078  ...  0.996078  0.996078  0.996078   bikes
# 1  0.271239  0.247343  0.201016  0.390128  ...  0.288458  0.339438  0.362967   bikes
# 2  0.255088  0.478617  0.788421  0.256122  ...  0.058051  0.265894  0.477658   bikes
# 3  0.373791  0.413688  0.224301  0.290143  ...  0.614953  0.576208  0.384052   bikes
# 4  0.988235  0.968627  0.882353  0.988235  ...  0.846484  0.783739  0.681778   bikes
#
# [5 rows x 67501 columns]

# %%
from skimage.color import rgb2gray

img_resize = resize(img_array,(50,50))
img_gray = rgb2gray(img_resize)
plt.imshow(img_gray,cmap='gray')
img_gray.size
# Out:
# 2500

# %%
flat_data[0]
# Out:
# array([0.99607843, 0.99607843, 0.99607843, ..., 0.99607843, 0.99607843,
#        0.99607843])

# %%
target
# Out:
# array(['bikes', 'bikes', 'bikes', 'bikes', 'bikes', 'bikes', 'bikes',
#        'bikes', 'bikes', 'bikes', 'bikes', 'cars', 'cars', 'cars', 'cars',
#        'cars', 'cars', 'cars', 'cars', 'cars', 'cars', 'cars', 'cars',
#        'cars'], dtype='<U5')

# %%
unique,count = np.unique(target,return_counts=True)
plt.bar(categories,count)
# Out:
# <BarContainer object of 2 artists>
